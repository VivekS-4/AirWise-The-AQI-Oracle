# %%
# %%time
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from statsmodels.tsa.arima.model import ARIMA
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# Load your dataset
# Assuming your dataset is stored in a CSV file
df = pd.read_csv('cleaned_data.csv')

# Specify the correct column name
column_name = 'NO2-H24'

# Function to train LSTM model with grid search
def train_lstm_model(data, column_name, lstm_units, dropout_rate, epochs):
    # Normalize the data
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(data[[column_name]])

    # Prepare data for LSTM
    def create_dataset(dataset, look_back=1):
        dataX, dataY = [], []
        for i in range(len(dataset) - look_back):
            a = dataset[i:(i + look_back), 0]
            dataX.append(a)
            dataY.append(dataset[i + look_back, 0])
        return np.array(dataX), np.array(dataY)

    look_back = 3  # You can adjust this parameter based on your dataset
    train_size = int(len(scaled_data) * 0.8)
    train, test = scaled_data[0:train_size, :], scaled_data[train_size:len(scaled_data), :]

    trainX, trainY = create_dataset(train, look_back)
    testX, testY = create_dataset(test, look_back)

    # Reshape the data for LSTM input
    trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
    testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

    # Build LSTM model
    model = Sequential()
    model.add(LSTM(lstm_units, input_shape=(1, look_back), return_sequences=True))
    model.add(Dropout(dropout_rate))
    model.add(LSTM(lstm_units))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1))
    
    optimizer = Adam(learning_rate=0.001)
    model.compile(loss='mean_squared_error', optimizer=optimizer)
    
    model.fit(trainX, trainY, epochs=epochs, batch_size=1, verbose=2)

    # Make predictions using LSTM model
    trainPredict = model.predict(trainX)
    testPredict = model.predict(testX)

    # Invert predictions to original scale
    trainPredict = scaler.inverse_transform(np.reshape(trainPredict, (trainPredict.shape[0], 1)))
    trainY = scaler.inverse_transform(np.reshape(trainY, (len(trainY), 1)))
    testPredict = scaler.inverse_transform(np.reshape(testPredict, (testPredict.shape[0], 1)))
    testY = scaler.inverse_transform(np.reshape(testY, (len(testY), 1)))

    # Plot the results
    plt.plot(np.concatenate([trainY, testY]))
    plt.plot(np.concatenate([trainPredict, testPredict]))
    plt.show()

    # Train ARIMA model on the residuals
    residuals = trainY - trainPredict
    model_arima = ARIMA(residuals, order=(5, 1, 0))
    model_arima_fit = model_arima.fit()

    # Forecast using ARIMA
    arima_forecast = model_arima_fit.forecast(steps=len(testY))[0]

    # Calculate the final prediction by adding LSTM prediction and ARIMA forecast
    final_prediction = testPredict + arima_forecast

    # Evaluate the model
    mse = mean_squared_error(testY, final_prediction)
    print(f'Mean Squared Error for {column_name} with LSTM units={lstm_units}, Dropout={dropout_rate}: {mse}')

# Grid search over LSTM units and dropout rates
for lstm_units in [50, 100]:
    for dropout_rate in [0.2, 0.5]:
        print(f"Training with LSTM units: {lstm_units}, Dropout rate: {dropout_rate}")
        train_lstm_model(df, column_name, lstm_units, dropout_rate, epochs=100)
# Out:
# WARNING:tensorflow:From C:\Users\rutvi\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Training with LSTM units: 50, Dropout rate: 0.2
# WARNING:tensorflow:From C:\Users\rutvi\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\rutvi\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 1749/1749 - 9s - loss: 0.0194 - 9s/epoch - 5ms/step
# Epoch 2/100
# 1749/1749 - 5s - loss: 0.0188 - 5s/epoch - 3ms/step
# Epoch 3/100
# 1749/1749 - 5s - loss: 0.0187 - 5s/epoch - 3ms/step
# Epoch 4/100
# 1749/1749 - 4s - loss: 0.0184 - 4s/epoch - 3ms/step
# Epoch 5/100
# 1749/1749 - 5s - loss: 0.0187 - 5s/epoch - 3ms/step
# Epoch 6/100
# 1749/1749 - 5s - loss: 0.0185 - 5s/epoch - 3ms/step
# Epoch 7/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 8/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 9/100
# 1749/1749 - 4s - loss: 0.0184 - 4s/epoch - 3ms/step
# Epoch 10/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 11/100
# 1749/1749 - 4s - loss: 0.0183 - 4s/epoch - 3ms/step
# Epoch 12/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 13/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 3ms/step
# Epoch 14/100
# 1749/1749 - 4s - loss: 0.0183 - 4s/epoch - 3ms/step
# Epoch 15/100
# 1749/1749 - 4s - loss: 0.0185 - 4s/epoch - 3ms/step
# Epoch 16/100
# 1749/1749 - 4s - loss: 0.0181 - 4s/epoch - 2ms/step
# Epoch 17/100
# 1749/1749 - 4s - loss: 0.0184 - 4s/epoch - 2ms/step
# Epoch 18/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 2ms/step
# Epoch 19/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 3ms/step
# Epoch 20/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 2ms/step
# Epoch 21/100
# 1749/1749 - 4s - loss: 0.0181 - 4s/epoch - 2ms/step
# Epoch 22/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 2ms/step
# Epoch 23/100
# 1749/1749 - 4s - loss: 0.0183 - 4s/epoch - 2ms/step
# Epoch 24/100
# 1749/1749 - 4s - loss: 0.0184 - 4s/epoch - 3ms/step
# Epoch 25/100
# 1749/1749 - 4s - loss: 0.0183 - 4s/epoch - 2ms/step
# Epoch 26/100
# 1749/1749 - 4s - loss: 0.0181 - 4s/epoch - 3ms/step
# Epoch 27/100
# 1749/1749 - 4s - loss: 0.0181 - 4s/epoch - 2ms/step
# Epoch 28/100
# 1749/1749 - 4s - loss: 0.0181 - 4s/epoch - 2ms/step
# Epoch 29/100
# 1749/1749 - 4s - loss: 0.0185 - 4s/epoch - 3ms/step
# Epoch 30/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 2ms/step
# Epoch 31/100
# 1749/1749 - 4s - loss: 0.0183 - 4s/epoch - 2ms/step
# Epoch 32/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 2ms/step
# Epoch 33/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 2ms/step
# Epoch 34/100
# 1749/1749 - 4s - loss: 0.0183 - 4s/epoch - 2ms/step
# Epoch 35/100
# 1749/1749 - 4s - loss: 0.0183 - 4s/epoch - 2ms/step
# Epoch 36/100
# 1749/1749 - 4s - loss: 0.0181 - 4s/epoch - 2ms/step
# Epoch 37/100
# 1749/1749 - 4s - loss: 0.0183 - 4s/epoch - 3ms/step
# Epoch 38/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 2ms/step
# Epoch 39/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 2ms/step
# Epoch 40/100
# 1749/1749 - 4s - loss: 0.0181 - 4s/epoch - 2ms/step
# Epoch 41/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 2ms/step
# Epoch 42/100
# 1749/1749 - 4s - loss: 0.0180 - 4s/epoch - 2ms/step
# Epoch 43/100
# 1749/1749 - 4s - loss: 0.0183 - 4s/epoch - 2ms/step
# Epoch 44/100
# 1749/1749 - 4s - loss: 0.0181 - 4s/epoch - 3ms/step
# Epoch 45/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 3ms/step
# Epoch 46/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 2ms/step
# Epoch 47/100
# 1749/1749 - 4s - loss: 0.0183 - 4s/epoch - 2ms/step
# Epoch 48/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 2ms/step
# Epoch 49/100
# 1749/1749 - 4s - loss: 0.0183 - 4s/epoch - 2ms/step
# Epoch 50/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 3ms/step
# Epoch 51/100
# 1749/1749 - 4s - loss: 0.0181 - 4s/epoch - 2ms/step
# Epoch 52/100
# 1749/1749 - 4s - loss: 0.0181 - 4s/epoch - 2ms/step
# Epoch 53/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 2ms/step
# Epoch 54/100
# 1749/1749 - 4s - loss: 0.0183 - 4s/epoch - 2ms/step
# Epoch 55/100
# 1749/1749 - 4s - loss: 0.0181 - 4s/epoch - 2ms/step
# Epoch 56/100
# 1749/1749 - 4s - loss: 0.0181 - 4s/epoch - 2ms/step
# Epoch 57/100
# 1749/1749 - 4s - loss: 0.0181 - 4s/epoch - 2ms/step
# Epoch 58/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 2ms/step
# Epoch 59/100
# 1749/1749 - 4s - loss: 0.0183 - 4s/epoch - 3ms/step
# Epoch 60/100
# 1749/1749 - 4s - loss: 0.0181 - 4s/epoch - 2ms/step
# Epoch 61/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 2ms/step
# Epoch 62/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 2ms/step
# Epoch 63/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 2ms/step
# Epoch 64/100
# 1749/1749 - 4s - loss: 0.0181 - 4s/epoch - 2ms/step
# Epoch 65/100
# 1749/1749 - 4s - loss: 0.0181 - 4s/epoch - 3ms/step
# Epoch 66/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 3ms/step
# Epoch 67/100
# 1749/1749 - 4s - loss: 0.0181 - 4s/epoch - 3ms/step
# Epoch 68/100
# 1749/1749 - 4s - loss: 0.0181 - 4s/epoch - 3ms/step
# Epoch 69/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 2ms/step
# Epoch 70/100
# 1749/1749 - 4s - loss: 0.0181 - 4s/epoch - 2ms/step
# Epoch 71/100
# 1749/1749 - 4s - loss: 0.0181 - 4s/epoch - 2ms/step
# Epoch 72/100
# 1749/1749 - 4s - loss: 0.0181 - 4s/epoch - 2ms/step
# Epoch 73/100
# 1749/1749 - 4s - loss: 0.0180 - 4s/epoch - 2ms/step
# Epoch 74/100
# 1749/1749 - 4s - loss: 0.0181 - 4s/epoch - 2ms/step
# Epoch 75/100
# 1749/1749 - 4s - loss: 0.0181 - 4s/epoch - 3ms/step
# Epoch 76/100
# 1749/1749 - 4s - loss: 0.0180 - 4s/epoch - 3ms/step
# Epoch 77/100
# 1749/1749 - 4s - loss: 0.0180 - 4s/epoch - 3ms/step
# Epoch 78/100
# 1749/1749 - 4s - loss: 0.0180 - 4s/epoch - 2ms/step
# Epoch 79/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 3ms/step
# Epoch 80/100
# 1749/1749 - 4s - loss: 0.0181 - 4s/epoch - 3ms/step
# Epoch 81/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 3ms/step
# Epoch 82/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 2ms/step
# Epoch 83/100
# 1749/1749 - 4s - loss: 0.0181 - 4s/epoch - 3ms/step
# Epoch 84/100
# 1749/1749 - 4s - loss: 0.0181 - 4s/epoch - 2ms/step
# Epoch 85/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 2ms/step
# Epoch 86/100
# 1749/1749 - 4s - loss: 0.0180 - 4s/epoch - 2ms/step
# Epoch 87/100
# 1749/1749 - 4s - loss: 0.0180 - 4s/epoch - 2ms/step
# Epoch 88/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 2ms/step
# Epoch 89/100
# 1749/1749 - 4s - loss: 0.0181 - 4s/epoch - 2ms/step
# Epoch 90/100
# 1749/1749 - 4s - loss: 0.0180 - 4s/epoch - 3ms/step
# Epoch 91/100
# 1749/1749 - 4s - loss: 0.0180 - 4s/epoch - 2ms/step
# Epoch 92/100
# 1749/1749 - 4s - loss: 0.0180 - 4s/epoch - 2ms/step
# Epoch 93/100
# 1749/1749 - 4s - loss: 0.0181 - 4s/epoch - 2ms/step
# Epoch 94/100
# 1749/1749 - 4s - loss: 0.0181 - 4s/epoch - 2ms/step
# Epoch 95/100
# 1749/1749 - 4s - loss: 0.0180 - 4s/epoch - 2ms/step
# Epoch 96/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 2ms/step
# Epoch 97/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 2ms/step
# Epoch 98/100
# 1749/1749 - 4s - loss: 0.0179 - 4s/epoch - 2ms/step
# Epoch 99/100
# 1749/1749 - 4s - loss: 0.0181 - 4s/epoch - 2ms/step
# Epoch 100/100
# 1749/1749 - 4s - loss: 0.0181 - 4s/epoch - 2ms/step
# 55/55 [==============================] - 1s 2ms/step
# 14/14 [==============================] - 0s 2ms/step
# Mean Squared Error for NO2-H24 with LSTM units=50, Dropout=0.2: 73.96990891564018
# Training with LSTM units: 50, Dropout rate: 0.5
# Epoch 1/100
# 1749/1749 - 8s - loss: 0.0198 - 8s/epoch - 5ms/step
# Epoch 2/100
# 1749/1749 - 4s - loss: 0.0193 - 4s/epoch - 2ms/step
# Epoch 3/100
# 1749/1749 - 5s - loss: 0.0189 - 5s/epoch - 3ms/step
# Epoch 4/100
# 1749/1749 - 5s - loss: 0.0189 - 5s/epoch - 3ms/step
# Epoch 5/100
# 1749/1749 - 4s - loss: 0.0184 - 4s/epoch - 2ms/step
# Epoch 6/100
# 1749/1749 - 4s - loss: 0.0186 - 4s/epoch - 2ms/step
# Epoch 7/100
# 1749/1749 - 4s - loss: 0.0187 - 4s/epoch - 2ms/step
# Epoch 8/100
# 1749/1749 - 4s - loss: 0.0185 - 4s/epoch - 2ms/step
# Epoch 9/100
# 1749/1749 - 4s - loss: 0.0185 - 4s/epoch - 2ms/step
# Epoch 10/100
# 1749/1749 - 4s - loss: 0.0185 - 4s/epoch - 2ms/step
# Epoch 11/100
# 1749/1749 - 4s - loss: 0.0185 - 4s/epoch - 2ms/step
# Epoch 12/100
# 1749/1749 - 4s - loss: 0.0186 - 4s/epoch - 2ms/step
# Epoch 13/100
# 1749/1749 - 4s - loss: 0.0186 - 4s/epoch - 2ms/step
# Epoch 14/100
# 1749/1749 - 4s - loss: 0.0184 - 4s/epoch - 2ms/step
# Epoch 15/100
# 1749/1749 - 4s - loss: 0.0187 - 4s/epoch - 2ms/step
# Epoch 16/100
# 1749/1749 - 4s - loss: 0.0185 - 4s/epoch - 2ms/step
# Epoch 17/100
# 1749/1749 - 4s - loss: 0.0185 - 4s/epoch - 2ms/step
# Epoch 18/100
# 1749/1749 - 4s - loss: 0.0186 - 4s/epoch - 3ms/step
# Epoch 19/100
# 1749/1749 - 4s - loss: 0.0184 - 4s/epoch - 3ms/step
# Epoch 20/100
# 1749/1749 - 4s - loss: 0.0185 - 4s/epoch - 2ms/step
# Epoch 21/100
# 1749/1749 - 4s - loss: 0.0183 - 4s/epoch - 2ms/step
# Epoch 22/100
# 1749/1749 - 4s - loss: 0.0185 - 4s/epoch - 2ms/step
# Epoch 23/100
# 1749/1749 - 4s - loss: 0.0183 - 4s/epoch - 2ms/step
# Epoch 24/100
# 1749/1749 - 4s - loss: 0.0183 - 4s/epoch - 2ms/step
# Epoch 25/100
# 1749/1749 - 4s - loss: 0.0186 - 4s/epoch - 2ms/step
# Epoch 26/100
# 1749/1749 - 4s - loss: 0.0184 - 4s/epoch - 2ms/step
# Epoch 27/100
# 1749/1749 - 4s - loss: 0.0186 - 4s/epoch - 2ms/step
# Epoch 28/100
# 1749/1749 - 4s - loss: 0.0184 - 4s/epoch - 2ms/step
# Epoch 29/100
# 1749/1749 - 4s - loss: 0.0184 - 4s/epoch - 2ms/step
# Epoch 30/100
# 1749/1749 - 4s - loss: 0.0183 - 4s/epoch - 3ms/step
# Epoch 31/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 3ms/step
# Epoch 32/100
# 1749/1749 - 4s - loss: 0.0184 - 4s/epoch - 2ms/step
# Epoch 33/100
# 1749/1749 - 4s - loss: 0.0183 - 4s/epoch - 3ms/step
# Epoch 34/100
# 1749/1749 - 4s - loss: 0.0184 - 4s/epoch - 3ms/step
# Epoch 35/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 2ms/step
# Epoch 36/100
# 1749/1749 - 4s - loss: 0.0185 - 4s/epoch - 2ms/step
# Epoch 37/100
# 1749/1749 - 4s - loss: 0.0184 - 4s/epoch - 3ms/step
# Epoch 38/100
# 1749/1749 - 4s - loss: 0.0185 - 4s/epoch - 2ms/step
# Epoch 39/100
# 1749/1749 - 4s - loss: 0.0184 - 4s/epoch - 2ms/step
# Epoch 40/100
# 1749/1749 - 4s - loss: 0.0183 - 4s/epoch - 2ms/step
# Epoch 41/100
# 1749/1749 - 4s - loss: 0.0185 - 4s/epoch - 2ms/step
# Epoch 42/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 2ms/step
# Epoch 43/100
# 1749/1749 - 4s - loss: 0.0184 - 4s/epoch - 3ms/step
# Epoch 44/100
# 1749/1749 - 4s - loss: 0.0184 - 4s/epoch - 2ms/step
# Epoch 45/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 2ms/step
# Epoch 46/100
# 1749/1749 - 4s - loss: 0.0185 - 4s/epoch - 2ms/step
# Epoch 47/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 3ms/step
# Epoch 48/100
# 1749/1749 - 4s - loss: 0.0183 - 4s/epoch - 3ms/step
# Epoch 49/100
# 1749/1749 - 4s - loss: 0.0185 - 4s/epoch - 2ms/step
# Epoch 50/100
# 1749/1749 - 4s - loss: 0.0184 - 4s/epoch - 2ms/step
# Epoch 51/100
# 1749/1749 - 4s - loss: 0.0185 - 4s/epoch - 2ms/step
# Epoch 52/100
# 1749/1749 - 4s - loss: 0.0184 - 4s/epoch - 2ms/step
# Epoch 53/100
# 1749/1749 - 4s - loss: 0.0186 - 4s/epoch - 2ms/step
# Epoch 54/100
# 1749/1749 - 4s - loss: 0.0183 - 4s/epoch - 2ms/step
# Epoch 55/100
# 1749/1749 - 4s - loss: 0.0184 - 4s/epoch - 2ms/step
# Epoch 56/100
# 1749/1749 - 4s - loss: 0.0184 - 4s/epoch - 2ms/step
# Epoch 57/100
# 1749/1749 - 4s - loss: 0.0183 - 4s/epoch - 2ms/step
# Epoch 58/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 2ms/step
# Epoch 59/100
# 1749/1749 - 4s - loss: 0.0185 - 4s/epoch - 2ms/step
# Epoch 60/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 2ms/step
# Epoch 61/100
# 1749/1749 - 4s - loss: 0.0183 - 4s/epoch - 2ms/step
# Epoch 62/100
# 1749/1749 - 4s - loss: 0.0185 - 4s/epoch - 2ms/step
# Epoch 63/100
# 1749/1749 - 4s - loss: 0.0184 - 4s/epoch - 2ms/step
# Epoch 64/100
# 1749/1749 - 4s - loss: 0.0186 - 4s/epoch - 2ms/step
# Epoch 65/100
# 1749/1749 - 4s - loss: 0.0185 - 4s/epoch - 2ms/step
# Epoch 66/100
# 1749/1749 - 4s - loss: 0.0183 - 4s/epoch - 2ms/step
# Epoch 67/100
# 1749/1749 - 4s - loss: 0.0184 - 4s/epoch - 2ms/step
# Epoch 68/100
# 1749/1749 - 4s - loss: 0.0184 - 4s/epoch - 2ms/step
# Epoch 69/100
# 1749/1749 - 4s - loss: 0.0183 - 4s/epoch - 2ms/step
# Epoch 70/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 71/100
# 1749/1749 - 4s - loss: 0.0183 - 4s/epoch - 3ms/step
# Epoch 72/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 73/100
# 1749/1749 - 4s - loss: 0.0184 - 4s/epoch - 2ms/step
# Epoch 74/100
# 1749/1749 - 4s - loss: 0.0183 - 4s/epoch - 2ms/step
# Epoch 75/100
# 1749/1749 - 4s - loss: 0.0183 - 4s/epoch - 2ms/step
# Epoch 76/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 2ms/step
# Epoch 77/100
# 1749/1749 - 4s - loss: 0.0181 - 4s/epoch - 3ms/step
# Epoch 78/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 3ms/step
# Epoch 79/100
# 1749/1749 - 4s - loss: 0.0184 - 4s/epoch - 3ms/step
# Epoch 80/100
# 1749/1749 - 4s - loss: 0.0184 - 4s/epoch - 3ms/step
# Epoch 81/100
# 1749/1749 - 4s - loss: 0.0183 - 4s/epoch - 3ms/step
# Epoch 82/100
# 1749/1749 - 4s - loss: 0.0182 - 4s/epoch - 3ms/step
# Epoch 83/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 84/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 85/100
# 1749/1749 - 4s - loss: 0.0184 - 4s/epoch - 3ms/step
# Epoch 86/100
# 1749/1749 - 4s - loss: 0.0184 - 4s/epoch - 3ms/step
# Epoch 87/100
# 1749/1749 - 4s - loss: 0.0183 - 4s/epoch - 2ms/step
# Epoch 88/100
# 1749/1749 - 4s - loss: 0.0183 - 4s/epoch - 3ms/step
# Epoch 89/100
# 1749/1749 - 4s - loss: 0.0184 - 4s/epoch - 2ms/step
# Epoch 90/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 91/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 92/100
# 1749/1749 - 5s - loss: 0.0181 - 5s/epoch - 3ms/step
# Epoch 93/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 94/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 95/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 96/100
# 1749/1749 - 4s - loss: 0.0184 - 4s/epoch - 3ms/step
# Epoch 97/100
# 1749/1749 - 4s - loss: 0.0184 - 4s/epoch - 2ms/step
# Epoch 98/100
# 1749/1749 - 4s - loss: 0.0184 - 4s/epoch - 3ms/step
# Epoch 99/100
# 1749/1749 - 4s - loss: 0.0184 - 4s/epoch - 3ms/step
# Epoch 100/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# 55/55 [==============================] - 1s 2ms/step
# 14/14 [==============================] - 0s 2ms/step
# Mean Squared Error for NO2-H24 with LSTM units=50, Dropout=0.5: 74.26420322379641
# Training with LSTM units: 100, Dropout rate: 0.2
# Epoch 1/100
# 1749/1749 - 9s - loss: 0.0193 - 9s/epoch - 5ms/step
# Epoch 2/100
# 1749/1749 - 5s - loss: 0.0186 - 5s/epoch - 3ms/step
# Epoch 3/100
# 1749/1749 - 5s - loss: 0.0187 - 5s/epoch - 3ms/step
# Epoch 4/100
# 1749/1749 - 5s - loss: 0.0186 - 5s/epoch - 3ms/step
# Epoch 5/100
# 1749/1749 - 5s - loss: 0.0185 - 5s/epoch - 3ms/step
# Epoch 6/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 7/100
# 1749/1749 - 5s - loss: 0.0185 - 5s/epoch - 3ms/step
# Epoch 8/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 9/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 10/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 11/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 12/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 13/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 14/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 15/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 16/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 17/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 18/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 19/100
# 1749/1749 - 5s - loss: 0.0185 - 5s/epoch - 3ms/step
# Epoch 20/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 21/100
# 1749/1749 - 5s - loss: 0.0185 - 5s/epoch - 3ms/step
# Epoch 22/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 23/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 24/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 25/100
# 1749/1749 - 5s - loss: 0.0181 - 5s/epoch - 3ms/step
# Epoch 26/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 27/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 28/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 29/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 30/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 31/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 32/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 33/100
# 1749/1749 - 5s - loss: 0.0181 - 5s/epoch - 3ms/step
# Epoch 34/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 35/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 36/100
# 1749/1749 - 5s - loss: 0.0181 - 5s/epoch - 3ms/step
# Epoch 37/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 38/100
# 1749/1749 - 5s - loss: 0.0181 - 5s/epoch - 3ms/step
# Epoch 39/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 40/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 41/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 42/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 43/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 44/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 45/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 46/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 47/100
# 1749/1749 - 5s - loss: 0.0181 - 5s/epoch - 3ms/step
# Epoch 48/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 49/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 50/100
# 1749/1749 - 5s - loss: 0.0181 - 5s/epoch - 3ms/step
# Epoch 51/100
# 1749/1749 - 5s - loss: 0.0181 - 5s/epoch - 3ms/step
# Epoch 52/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 53/100
# 1749/1749 - 5s - loss: 0.0180 - 5s/epoch - 3ms/step
# Epoch 54/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 55/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 56/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 57/100
# 1749/1749 - 5s - loss: 0.0181 - 5s/epoch - 3ms/step
# Epoch 58/100
# 1749/1749 - 5s - loss: 0.0181 - 5s/epoch - 3ms/step
# Epoch 59/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 60/100
# 1749/1749 - 5s - loss: 0.0181 - 5s/epoch - 3ms/step
# Epoch 61/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 62/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 63/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 64/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 65/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 66/100
# 1749/1749 - 5s - loss: 0.0181 - 5s/epoch - 3ms/step
# Epoch 67/100
# 1749/1749 - 5s - loss: 0.0181 - 5s/epoch - 3ms/step
# Epoch 68/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 69/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 70/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 71/100
# 1749/1749 - 5s - loss: 0.0181 - 5s/epoch - 3ms/step
# Epoch 72/100
# 1749/1749 - 5s - loss: 0.0180 - 5s/epoch - 3ms/step
# Epoch 73/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 74/100
# 1749/1749 - 5s - loss: 0.0181 - 5s/epoch - 3ms/step
# Epoch 75/100
# 1749/1749 - 5s - loss: 0.0181 - 5s/epoch - 3ms/step
# Epoch 76/100
# 1749/1749 - 5s - loss: 0.0181 - 5s/epoch - 3ms/step
# Epoch 77/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 78/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 79/100
# 1749/1749 - 5s - loss: 0.0181 - 5s/epoch - 3ms/step
# Epoch 80/100
# 1749/1749 - 5s - loss: 0.0180 - 5s/epoch - 3ms/step
# Epoch 81/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 82/100
# 1749/1749 - 5s - loss: 0.0181 - 5s/epoch - 3ms/step
# Epoch 83/100
# 1749/1749 - 5s - loss: 0.0181 - 5s/epoch - 3ms/step
# Epoch 84/100
# 1749/1749 - 5s - loss: 0.0181 - 5s/epoch - 3ms/step
# Epoch 85/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 86/100
# 1749/1749 - 5s - loss: 0.0180 - 5s/epoch - 3ms/step
# Epoch 87/100
# 1749/1749 - 5s - loss: 0.0180 - 5s/epoch - 3ms/step
# Epoch 88/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 89/100
# 1749/1749 - 5s - loss: 0.0180 - 5s/epoch - 3ms/step
# Epoch 90/100
# 1749/1749 - 5s - loss: 0.0179 - 5s/epoch - 3ms/step
# Epoch 91/100
# 1749/1749 - 5s - loss: 0.0181 - 5s/epoch - 3ms/step
# Epoch 92/100
# 1749/1749 - 5s - loss: 0.0181 - 5s/epoch - 3ms/step
# Epoch 93/100
# 1749/1749 - 5s - loss: 0.0181 - 5s/epoch - 3ms/step
# Epoch 94/100
# 1749/1749 - 5s - loss: 0.0180 - 5s/epoch - 3ms/step
# Epoch 95/100
# 1749/1749 - 5s - loss: 0.0180 - 5s/epoch - 3ms/step
# Epoch 96/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 97/100
# 1749/1749 - 5s - loss: 0.0180 - 5s/epoch - 3ms/step
# Epoch 98/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 99/100
# 1749/1749 - 5s - loss: 0.0181 - 5s/epoch - 3ms/step
# Epoch 100/100
# 1749/1749 - 5s - loss: 0.0181 - 5s/epoch - 3ms/step
# 55/55 [==============================] - 1s 2ms/step
# 14/14 [==============================] - 0s 2ms/step
# Mean Squared Error for NO2-H24 with LSTM units=100, Dropout=0.2: 75.1612260827837
# Training with LSTM units: 100, Dropout rate: 0.5
# Epoch 1/100
# 1749/1749 - 9s - loss: 0.0199 - 9s/epoch - 5ms/step
# Epoch 2/100
# 1749/1749 - 5s - loss: 0.0187 - 5s/epoch - 3ms/step
# Epoch 3/100
# 1749/1749 - 5s - loss: 0.0192 - 5s/epoch - 3ms/step
# Epoch 4/100
# 1749/1749 - 5s - loss: 0.0190 - 5s/epoch - 3ms/step
# Epoch 5/100
# 1749/1749 - 5s - loss: 0.0186 - 5s/epoch - 3ms/step
# Epoch 6/100
# 1749/1749 - 5s - loss: 0.0187 - 5s/epoch - 3ms/step
# Epoch 7/100
# 1749/1749 - 5s - loss: 0.0187 - 5s/epoch - 3ms/step
# Epoch 8/100
# 1749/1749 - 5s - loss: 0.0186 - 5s/epoch - 3ms/step
# Epoch 9/100
# 1749/1749 - 5s - loss: 0.0185 - 5s/epoch - 3ms/step
# Epoch 10/100
# 1749/1749 - 5s - loss: 0.0185 - 5s/epoch - 3ms/step
# Epoch 11/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 12/100
# 1749/1749 - 5s - loss: 0.0186 - 5s/epoch - 3ms/step
# Epoch 13/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 14/100
# 1749/1749 - 5s - loss: 0.0185 - 5s/epoch - 3ms/step
# Epoch 15/100
# 1749/1749 - 5s - loss: 0.0185 - 5s/epoch - 3ms/step
# Epoch 16/100
# 1749/1749 - 5s - loss: 0.0186 - 5s/epoch - 3ms/step
# Epoch 17/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 18/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 19/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 20/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 21/100
# 1749/1749 - 5s - loss: 0.0185 - 5s/epoch - 3ms/step
# Epoch 22/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 23/100
# 1749/1749 - 5s - loss: 0.0185 - 5s/epoch - 3ms/step
# Epoch 24/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 25/100
# 1749/1749 - 5s - loss: 0.0186 - 5s/epoch - 3ms/step
# Epoch 26/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 27/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 28/100
# 1749/1749 - 5s - loss: 0.0186 - 5s/epoch - 3ms/step
# Epoch 29/100
# 1749/1749 - 5s - loss: 0.0185 - 5s/epoch - 3ms/step
# Epoch 30/100
# 1749/1749 - 5s - loss: 0.0185 - 5s/epoch - 3ms/step
# Epoch 31/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 32/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 33/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 34/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 35/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 36/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 37/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 38/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 39/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 40/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 41/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 42/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 43/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 44/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 45/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 46/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 47/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 48/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 49/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 50/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 51/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 52/100
# 1749/1749 - 5s - loss: 0.0181 - 5s/epoch - 3ms/step
# Epoch 53/100
# 1749/1749 - 5s - loss: 0.0180 - 5s/epoch - 3ms/step
# Epoch 54/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 55/100
# 1749/1749 - 5s - loss: 0.0186 - 5s/epoch - 3ms/step
# Epoch 56/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 57/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 58/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 59/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 60/100
# 1749/1749 - 5s - loss: 0.0186 - 5s/epoch - 3ms/step
# Epoch 61/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 62/100
# 1749/1749 - 5s - loss: 0.0185 - 5s/epoch - 3ms/step
# Epoch 63/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 64/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 65/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 66/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 67/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 68/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 69/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 70/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 71/100
# 1749/1749 - 5s - loss: 0.0181 - 5s/epoch - 3ms/step
# Epoch 72/100
# 1749/1749 - 5s - loss: 0.0181 - 5s/epoch - 3ms/step
# Epoch 73/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 74/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 75/100
# 1749/1749 - 5s - loss: 0.0181 - 5s/epoch - 3ms/step
# Epoch 76/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 77/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 78/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 79/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 80/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 81/100
# 1749/1749 - 5s - loss: 0.0181 - 5s/epoch - 3ms/step
# Epoch 82/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 83/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 84/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 85/100
# 1749/1749 - 5s - loss: 0.0181 - 5s/epoch - 3ms/step
# Epoch 86/100
# 1749/1749 - 5s - loss: 0.0181 - 5s/epoch - 3ms/step
# Epoch 87/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 88/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 89/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 90/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 91/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 92/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 93/100
# 1749/1749 - 5s - loss: 0.0184 - 5s/epoch - 3ms/step
# Epoch 94/100
# 1749/1749 - 5s - loss: 0.0183 - 5s/epoch - 3ms/step
# Epoch 95/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 96/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 97/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 98/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# Epoch 99/100
# 1749/1749 - 5s - loss: 0.0180 - 5s/epoch - 3ms/step
# Epoch 100/100
# 1749/1749 - 5s - loss: 0.0182 - 5s/epoch - 3ms/step
# 55/55 [==============================] - 1s 2ms/step
# 14/14 [==============================] - 0s 2ms/step
# Mean Squared Error for NO2-H24 with LSTM units=100, Dropout=0.5: 72.92305704861225
# CPU times: total: 33min 47s
# Wall time: 31min 9s
