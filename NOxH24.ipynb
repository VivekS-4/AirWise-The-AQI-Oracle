# %%
# %%time
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from statsmodels.tsa.arima.model import ARIMA
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt


# Load your dataset
# Assuming your dataset is stored in a CSV file
df = pd.read_csv('cleaned_data.csv')

# Specify the correct O3 column name
NOxcolumn = 'NOx-H24'  # Update this with the correct column name for O3


# Function to train LSTM model for O3 pollutant column
def train_lstm_model(data, column_name):
    # Normalize the data
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(data[[column_name]])

    # Prepare data for LSTM
    def create_dataset(dataset, look_back=1):
        dataX, dataY = [], []
        for i in range(len(dataset) - look_back):
            a = dataset[i:(i + look_back), 0]
            dataX.append(a)
            dataY.append(dataset[i + look_back, 0])
        return np.array(dataX), np.array(dataY)

    look_back = 10  # Increase the look_back value for capturing more temporal patterns
    train_size = int(len(scaled_data) * 0.8)
    train, test = scaled_data[0:train_size, :], scaled_data[train_size:len(scaled_data), :]

    trainX, trainY = create_dataset(train, look_back)
    testX, testY = create_dataset(test, look_back)

    # Reshape the data for LSTM input
    trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
    testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

    # Build LSTM model with more complexity
    model = Sequential()
    model.add(LSTM(100, input_shape=(1, look_back), return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(100, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(100))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    model.fit(trainX, trainY, epochs=200, batch_size=32, verbose=2)

    # Make predictions using LSTM model
    trainPredict = model.predict(trainX)
    testPredict = model.predict(testX)

    # Invert predictions to original scale
    trainPredict = scaler.inverse_transform(np.reshape(trainPredict, (trainPredict.shape[0], 1)))
    trainY = scaler.inverse_transform(np.reshape(trainY, (len(trainY), 1)))
    testPredict = scaler.inverse_transform(np.reshape(testPredict, (testPredict.shape[0], 1)))
    testY = scaler.inverse_transform(np.reshape(testY, (len(testY), 1)))

    # Plot the results
    plt.plot(np.concatenate([trainY, testY]))
    plt.plot(np.concatenate([trainPredict, testPredict]))
    plt.show()

    # Train ARIMA model on the residuals
    residuals = trainY - trainPredict
    model_arima = ARIMA(residuals, order=(5, 2, 1))
    model_arima_fit = model_arima.fit()

    # Forecast using ARIMA
    arima_forecast = model_arima_fit.forecast(steps=len(testY))[0]

    # Calculate the final prediction by adding LSTM prediction and ARIMA forecast
    final_prediction = testPredict + arima_forecast

    # Evaluate the model
    mse = mean_squared_error(testY, final_prediction)
    print(f'Mean Squared Error for {column_name}: {mse}')

# Train LSTM and ARIMA for O3 pollutant column
train_lstm_model(df, NOxcolumn)
# Out:
# WARNING:tensorflow:From C:\Users\rutvi\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\rutvi\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\rutvi\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/200
# WARNING:tensorflow:From C:\Users\rutvi\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 55/55 - 8s - loss: 0.0086 - 8s/epoch - 151ms/step
# Epoch 2/200
# 55/55 - 0s - loss: 0.0074 - 312ms/epoch - 6ms/step
# Epoch 3/200
# 55/55 - 0s - loss: 0.0074 - 312ms/epoch - 6ms/step
# Epoch 4/200
# 55/55 - 0s - loss: 0.0073 - 308ms/epoch - 6ms/step
# Epoch 5/200
# 55/55 - 0s - loss: 0.0073 - 321ms/epoch - 6ms/step
# Epoch 6/200
# 55/55 - 0s - loss: 0.0072 - 304ms/epoch - 6ms/step
# Epoch 7/200
# 55/55 - 0s - loss: 0.0073 - 317ms/epoch - 6ms/step
# Epoch 8/200
# 55/55 - 0s - loss: 0.0072 - 328ms/epoch - 6ms/step
# Epoch 9/200
# 55/55 - 0s - loss: 0.0072 - 312ms/epoch - 6ms/step
# Epoch 10/200
# 55/55 - 0s - loss: 0.0072 - 313ms/epoch - 6ms/step
# Epoch 11/200
# 55/55 - 0s - loss: 0.0072 - 317ms/epoch - 6ms/step
# Epoch 12/200
# 55/55 - 0s - loss: 0.0072 - 313ms/epoch - 6ms/step
# Epoch 13/200
# 55/55 - 0s - loss: 0.0071 - 310ms/epoch - 6ms/step
# Epoch 14/200
# 55/55 - 0s - loss: 0.0072 - 317ms/epoch - 6ms/step
# Epoch 15/200
# 55/55 - 0s - loss: 0.0072 - 312ms/epoch - 6ms/step
# Epoch 16/200
# 55/55 - 0s - loss: 0.0072 - 320ms/epoch - 6ms/step
# Epoch 17/200
# 55/55 - 0s - loss: 0.0071 - 316ms/epoch - 6ms/step
# Epoch 18/200
# 55/55 - 0s - loss: 0.0072 - 316ms/epoch - 6ms/step
# Epoch 19/200
# 55/55 - 0s - loss: 0.0072 - 308ms/epoch - 6ms/step
# Epoch 20/200
# 55/55 - 0s - loss: 0.0072 - 314ms/epoch - 6ms/step
# Epoch 21/200
# 55/55 - 0s - loss: 0.0072 - 317ms/epoch - 6ms/step
# Epoch 22/200
# 55/55 - 0s - loss: 0.0072 - 321ms/epoch - 6ms/step
# Epoch 23/200
# 55/55 - 0s - loss: 0.0072 - 317ms/epoch - 6ms/step
# Epoch 24/200
# 55/55 - 0s - loss: 0.0072 - 325ms/epoch - 6ms/step
# Epoch 25/200
# 55/55 - 0s - loss: 0.0072 - 315ms/epoch - 6ms/step
# Epoch 26/200
# 55/55 - 0s - loss: 0.0072 - 308ms/epoch - 6ms/step
# Epoch 27/200
# 55/55 - 0s - loss: 0.0071 - 318ms/epoch - 6ms/step
# Epoch 28/200
# 55/55 - 0s - loss: 0.0072 - 325ms/epoch - 6ms/step
# Epoch 29/200
# 55/55 - 0s - loss: 0.0071 - 317ms/epoch - 6ms/step
# Epoch 30/200
# 55/55 - 0s - loss: 0.0072 - 321ms/epoch - 6ms/step
# Epoch 31/200
# 55/55 - 0s - loss: 0.0072 - 324ms/epoch - 6ms/step
# Epoch 32/200
# 55/55 - 0s - loss: 0.0072 - 312ms/epoch - 6ms/step
# Epoch 33/200
# 55/55 - 0s - loss: 0.0072 - 316ms/epoch - 6ms/step
# Epoch 34/200
# 55/55 - 0s - loss: 0.0072 - 311ms/epoch - 6ms/step
# Epoch 35/200
# 55/55 - 0s - loss: 0.0071 - 279ms/epoch - 5ms/step
# Epoch 36/200
# 55/55 - 0s - loss: 0.0072 - 273ms/epoch - 5ms/step
# Epoch 37/200
# 55/55 - 0s - loss: 0.0072 - 295ms/epoch - 5ms/step
# Epoch 38/200
# 55/55 - 0s - loss: 0.0071 - 285ms/epoch - 5ms/step
# Epoch 39/200
# 55/55 - 0s - loss: 0.0071 - 296ms/epoch - 5ms/step
# Epoch 40/200
# 55/55 - 0s - loss: 0.0071 - 317ms/epoch - 6ms/step
# Epoch 41/200
# 55/55 - 0s - loss: 0.0071 - 294ms/epoch - 5ms/step
# Epoch 42/200
# 55/55 - 0s - loss: 0.0072 - 283ms/epoch - 5ms/step
# Epoch 43/200
# 55/55 - 0s - loss: 0.0071 - 279ms/epoch - 5ms/step
# Epoch 44/200
# 55/55 - 0s - loss: 0.0071 - 278ms/epoch - 5ms/step
# Epoch 45/200
# 55/55 - 0s - loss: 0.0070 - 284ms/epoch - 5ms/step
# Epoch 46/200
# 55/55 - 0s - loss: 0.0071 - 312ms/epoch - 6ms/step
# Epoch 47/200
# 55/55 - 0s - loss: 0.0071 - 288ms/epoch - 5ms/step
# Epoch 48/200
# 55/55 - 0s - loss: 0.0071 - 266ms/epoch - 5ms/step
# Epoch 49/200
# 55/55 - 0s - loss: 0.0071 - 267ms/epoch - 5ms/step
# Epoch 50/200
# 55/55 - 0s - loss: 0.0070 - 266ms/epoch - 5ms/step
# Epoch 51/200
# 55/55 - 0s - loss: 0.0070 - 267ms/epoch - 5ms/step
# Epoch 52/200
# 55/55 - 0s - loss: 0.0070 - 288ms/epoch - 5ms/step
# Epoch 53/200
# 55/55 - 0s - loss: 0.0071 - 283ms/epoch - 5ms/step
# Epoch 54/200
# 55/55 - 0s - loss: 0.0070 - 291ms/epoch - 5ms/step
# Epoch 55/200
# 55/55 - 0s - loss: 0.0070 - 283ms/epoch - 5ms/step
# Epoch 56/200
# 55/55 - 0s - loss: 0.0070 - 290ms/epoch - 5ms/step
# Epoch 57/200
# 55/55 - 0s - loss: 0.0070 - 296ms/epoch - 5ms/step
# Epoch 58/200
# 55/55 - 0s - loss: 0.0070 - 284ms/epoch - 5ms/step
# Epoch 59/200
# 55/55 - 0s - loss: 0.0070 - 279ms/epoch - 5ms/step
# Epoch 60/200
# 55/55 - 0s - loss: 0.0070 - 284ms/epoch - 5ms/step
# Epoch 61/200
# 55/55 - 0s - loss: 0.0071 - 281ms/epoch - 5ms/step
# Epoch 62/200
# 55/55 - 0s - loss: 0.0071 - 281ms/epoch - 5ms/step
# Epoch 63/200
# 55/55 - 0s - loss: 0.0069 - 283ms/epoch - 5ms/step
# Epoch 64/200
# 55/55 - 0s - loss: 0.0070 - 279ms/epoch - 5ms/step
# Epoch 65/200
# 55/55 - 0s - loss: 0.0070 - 271ms/epoch - 5ms/step
# Epoch 66/200
# 55/55 - 0s - loss: 0.0070 - 283ms/epoch - 5ms/step
# Epoch 67/200
# 55/55 - 0s - loss: 0.0070 - 282ms/epoch - 5ms/step
# Epoch 68/200
# 55/55 - 0s - loss: 0.0069 - 285ms/epoch - 5ms/step
# Epoch 69/200
# 55/55 - 0s - loss: 0.0070 - 285ms/epoch - 5ms/step
# Epoch 70/200
# 55/55 - 0s - loss: 0.0070 - 279ms/epoch - 5ms/step
# Epoch 71/200
# 55/55 - 0s - loss: 0.0070 - 291ms/epoch - 5ms/step
# Epoch 72/200
# 55/55 - 0s - loss: 0.0070 - 282ms/epoch - 5ms/step
# Epoch 73/200
# 55/55 - 0s - loss: 0.0069 - 268ms/epoch - 5ms/step
# Epoch 74/200
# 55/55 - 0s - loss: 0.0070 - 269ms/epoch - 5ms/step
# Epoch 75/200
# 55/55 - 0s - loss: 0.0070 - 289ms/epoch - 5ms/step
# Epoch 76/200
# 55/55 - 0s - loss: 0.0069 - 272ms/epoch - 5ms/step
# Epoch 77/200
# 55/55 - 0s - loss: 0.0070 - 298ms/epoch - 5ms/step
# Epoch 78/200
# 55/55 - 0s - loss: 0.0069 - 285ms/epoch - 5ms/step
# Epoch 79/200
# 55/55 - 0s - loss: 0.0070 - 290ms/epoch - 5ms/step
# Epoch 80/200
# 55/55 - 0s - loss: 0.0069 - 284ms/epoch - 5ms/step
# Epoch 81/200
# 55/55 - 0s - loss: 0.0070 - 276ms/epoch - 5ms/step
# Epoch 82/200
# 55/55 - 0s - loss: 0.0069 - 281ms/epoch - 5ms/step
# Epoch 83/200
# 55/55 - 0s - loss: 0.0070 - 283ms/epoch - 5ms/step
# Epoch 84/200
# 55/55 - 0s - loss: 0.0069 - 286ms/epoch - 5ms/step
# Epoch 85/200
# 55/55 - 0s - loss: 0.0070 - 276ms/epoch - 5ms/step
# Epoch 86/200
# 55/55 - 0s - loss: 0.0070 - 283ms/epoch - 5ms/step
# Epoch 87/200
# 55/55 - 0s - loss: 0.0069 - 282ms/epoch - 5ms/step
# Epoch 88/200
# 55/55 - 0s - loss: 0.0069 - 291ms/epoch - 5ms/step
# Epoch 89/200
# 55/55 - 0s - loss: 0.0070 - 288ms/epoch - 5ms/step
# Epoch 90/200
# 55/55 - 0s - loss: 0.0070 - 283ms/epoch - 5ms/step
# Epoch 91/200
# 55/55 - 0s - loss: 0.0069 - 286ms/epoch - 5ms/step
# Epoch 92/200
# 55/55 - 0s - loss: 0.0069 - 292ms/epoch - 5ms/step
# Epoch 93/200
# 55/55 - 0s - loss: 0.0070 - 276ms/epoch - 5ms/step
# Epoch 94/200
# 55/55 - 0s - loss: 0.0071 - 267ms/epoch - 5ms/step
# Epoch 95/200
# 55/55 - 0s - loss: 0.0070 - 298ms/epoch - 5ms/step
# Epoch 96/200
# 55/55 - 0s - loss: 0.0069 - 288ms/epoch - 5ms/step
# Epoch 97/200
# 55/55 - 0s - loss: 0.0069 - 275ms/epoch - 5ms/step
# Epoch 98/200
# 55/55 - 0s - loss: 0.0069 - 290ms/epoch - 5ms/step
# Epoch 99/200
# 55/55 - 0s - loss: 0.0069 - 282ms/epoch - 5ms/step
# Epoch 100/200
# 55/55 - 0s - loss: 0.0070 - 275ms/epoch - 5ms/step
# Epoch 101/200
# 55/55 - 0s - loss: 0.0069 - 283ms/epoch - 5ms/step
# Epoch 102/200
# 55/55 - 0s - loss: 0.0068 - 281ms/epoch - 5ms/step
# Epoch 103/200
# 55/55 - 0s - loss: 0.0068 - 291ms/epoch - 5ms/step
# Epoch 104/200
# 55/55 - 0s - loss: 0.0069 - 290ms/epoch - 5ms/step
# Epoch 105/200
# 55/55 - 0s - loss: 0.0069 - 283ms/epoch - 5ms/step
# Epoch 106/200
# 55/55 - 0s - loss: 0.0069 - 280ms/epoch - 5ms/step
# Epoch 107/200
# 55/55 - 0s - loss: 0.0069 - 283ms/epoch - 5ms/step
# Epoch 108/200
# 55/55 - 0s - loss: 0.0069 - 279ms/epoch - 5ms/step
# Epoch 109/200
# 55/55 - 0s - loss: 0.0069 - 279ms/epoch - 5ms/step
# Epoch 110/200
# 55/55 - 0s - loss: 0.0069 - 282ms/epoch - 5ms/step
# Epoch 111/200
# 55/55 - 0s - loss: 0.0069 - 295ms/epoch - 5ms/step
# Epoch 112/200
# 55/55 - 0s - loss: 0.0069 - 283ms/epoch - 5ms/step
# Epoch 113/200
# 55/55 - 0s - loss: 0.0069 - 276ms/epoch - 5ms/step
# Epoch 114/200
# 55/55 - 0s - loss: 0.0069 - 290ms/epoch - 5ms/step
# Epoch 115/200
# 55/55 - 0s - loss: 0.0069 - 281ms/epoch - 5ms/step
# Epoch 116/200
# 55/55 - 0s - loss: 0.0069 - 283ms/epoch - 5ms/step
# Epoch 117/200
# 55/55 - 0s - loss: 0.0068 - 289ms/epoch - 5ms/step
# Epoch 118/200
# 55/55 - 0s - loss: 0.0069 - 283ms/epoch - 5ms/step
# Epoch 119/200
# 55/55 - 0s - loss: 0.0069 - 291ms/epoch - 5ms/step
# Epoch 120/200
# 55/55 - 0s - loss: 0.0068 - 283ms/epoch - 5ms/step
# Epoch 121/200
# 55/55 - 0s - loss: 0.0070 - 281ms/epoch - 5ms/step
# Epoch 122/200
# 55/55 - 0s - loss: 0.0070 - 283ms/epoch - 5ms/step
# Epoch 123/200
# 55/55 - 0s - loss: 0.0068 - 289ms/epoch - 5ms/step
# Epoch 124/200
# 55/55 - 0s - loss: 0.0068 - 268ms/epoch - 5ms/step
# Epoch 125/200
# 55/55 - 0s - loss: 0.0069 - 281ms/epoch - 5ms/step
# Epoch 126/200
# 55/55 - 0s - loss: 0.0068 - 284ms/epoch - 5ms/step
# Epoch 127/200
# 55/55 - 0s - loss: 0.0069 - 283ms/epoch - 5ms/step
# Epoch 128/200
# 55/55 - 0s - loss: 0.0069 - 277ms/epoch - 5ms/step
# Epoch 129/200
# 55/55 - 0s - loss: 0.0068 - 281ms/epoch - 5ms/step
# Epoch 130/200
# 55/55 - 0s - loss: 0.0068 - 280ms/epoch - 5ms/step
# Epoch 131/200
# 55/55 - 0s - loss: 0.0068 - 282ms/epoch - 5ms/step
# Epoch 132/200
# 55/55 - 0s - loss: 0.0068 - 290ms/epoch - 5ms/step
# Epoch 133/200
# 55/55 - 0s - loss: 0.0068 - 283ms/epoch - 5ms/step
# Epoch 134/200
# 55/55 - 0s - loss: 0.0070 - 290ms/epoch - 5ms/step
# Epoch 135/200
# 55/55 - 0s - loss: 0.0069 - 283ms/epoch - 5ms/step
# Epoch 136/200
# 55/55 - 0s - loss: 0.0068 - 282ms/epoch - 5ms/step
# Epoch 137/200
# 55/55 - 0s - loss: 0.0067 - 298ms/epoch - 5ms/step
# Epoch 138/200
# 55/55 - 0s - loss: 0.0069 - 277ms/epoch - 5ms/step
# Epoch 139/200
# 55/55 - 0s - loss: 0.0068 - 285ms/epoch - 5ms/step
# Epoch 140/200
# 55/55 - 0s - loss: 0.0067 - 267ms/epoch - 5ms/step
# Epoch 141/200
# 55/55 - 0s - loss: 0.0068 - 274ms/epoch - 5ms/step
# Epoch 142/200
# 55/55 - 0s - loss: 0.0069 - 283ms/epoch - 5ms/step
# Epoch 143/200
# 55/55 - 0s - loss: 0.0068 - 282ms/epoch - 5ms/step
# Epoch 144/200
# 55/55 - 0s - loss: 0.0068 - 283ms/epoch - 5ms/step
# Epoch 145/200
# 55/55 - 0s - loss: 0.0068 - 282ms/epoch - 5ms/step
# Epoch 146/200
# 55/55 - 0s - loss: 0.0069 - 282ms/epoch - 5ms/step
# Epoch 147/200
# 55/55 - 0s - loss: 0.0068 - 279ms/epoch - 5ms/step
# Epoch 148/200
# 55/55 - 0s - loss: 0.0068 - 283ms/epoch - 5ms/step
# Epoch 149/200
# 55/55 - 0s - loss: 0.0068 - 288ms/epoch - 5ms/step
# Epoch 150/200
# 55/55 - 0s - loss: 0.0067 - 283ms/epoch - 5ms/step
# Epoch 151/200
# 55/55 - 0s - loss: 0.0068 - 282ms/epoch - 5ms/step
# Epoch 152/200
# 55/55 - 0s - loss: 0.0068 - 294ms/epoch - 5ms/step
# Epoch 153/200
# 55/55 - 0s - loss: 0.0068 - 268ms/epoch - 5ms/step
# Epoch 154/200
# 55/55 - 0s - loss: 0.0069 - 291ms/epoch - 5ms/step
# Epoch 155/200
# 55/55 - 0s - loss: 0.0067 - 283ms/epoch - 5ms/step
# Epoch 156/200
# 55/55 - 0s - loss: 0.0067 - 289ms/epoch - 5ms/step
# Epoch 157/200
# 55/55 - 0s - loss: 0.0068 - 283ms/epoch - 5ms/step
# Epoch 158/200
# 55/55 - 0s - loss: 0.0067 - 289ms/epoch - 5ms/step
# Epoch 159/200
# 55/55 - 0s - loss: 0.0067 - 283ms/epoch - 5ms/step
# Epoch 160/200
# 55/55 - 0s - loss: 0.0067 - 279ms/epoch - 5ms/step
# Epoch 161/200
# 55/55 - 0s - loss: 0.0068 - 293ms/epoch - 5ms/step
# Epoch 162/200
# 55/55 - 0s - loss: 0.0068 - 287ms/epoch - 5ms/step
# Epoch 163/200
# 55/55 - 0s - loss: 0.0068 - 283ms/epoch - 5ms/step
# Epoch 164/200
# 55/55 - 0s - loss: 0.0067 - 291ms/epoch - 5ms/step
# Epoch 165/200
# 55/55 - 0s - loss: 0.0067 - 274ms/epoch - 5ms/step
# Epoch 166/200
# 55/55 - 0s - loss: 0.0068 - 299ms/epoch - 5ms/step
# Epoch 167/200
# 55/55 - 0s - loss: 0.0068 - 274ms/epoch - 5ms/step
# Epoch 168/200
# 55/55 - 0s - loss: 0.0067 - 283ms/epoch - 5ms/step
# Epoch 169/200
# 55/55 - 0s - loss: 0.0066 - 266ms/epoch - 5ms/step
# Epoch 170/200
# 55/55 - 0s - loss: 0.0068 - 283ms/epoch - 5ms/step
# Epoch 171/200
# 55/55 - 0s - loss: 0.0067 - 278ms/epoch - 5ms/step
# Epoch 172/200
# 55/55 - 0s - loss: 0.0067 - 285ms/epoch - 5ms/step
# Epoch 173/200
# 55/55 - 0s - loss: 0.0068 - 283ms/epoch - 5ms/step
# Epoch 174/200
# 55/55 - 0s - loss: 0.0065 - 283ms/epoch - 5ms/step
# Epoch 175/200
# 55/55 - 0s - loss: 0.0066 - 281ms/epoch - 5ms/step
# Epoch 176/200
# 55/55 - 0s - loss: 0.0066 - 283ms/epoch - 5ms/step
# Epoch 177/200
# 55/55 - 0s - loss: 0.0065 - 296ms/epoch - 5ms/step
# Epoch 178/200
# 55/55 - 0s - loss: 0.0065 - 289ms/epoch - 5ms/step
# Epoch 179/200
# 55/55 - 0s - loss: 0.0067 - 283ms/epoch - 5ms/step
# Epoch 180/200
# 55/55 - 0s - loss: 0.0067 - 274ms/epoch - 5ms/step
# Epoch 181/200
# 55/55 - 0s - loss: 0.0067 - 282ms/epoch - 5ms/step
# Epoch 182/200
# 55/55 - 0s - loss: 0.0066 - 275ms/epoch - 5ms/step
# Epoch 183/200
# 55/55 - 0s - loss: 0.0066 - 283ms/epoch - 5ms/step
# Epoch 184/200
# 55/55 - 0s - loss: 0.0067 - 280ms/epoch - 5ms/step
# Epoch 185/200
# 55/55 - 0s - loss: 0.0066 - 269ms/epoch - 5ms/step
# Epoch 186/200
# 55/55 - 0s - loss: 0.0065 - 289ms/epoch - 5ms/step
# Epoch 187/200
# 55/55 - 0s - loss: 0.0067 - 283ms/epoch - 5ms/step
# Epoch 188/200
# 55/55 - 0s - loss: 0.0066 - 279ms/epoch - 5ms/step
# Epoch 189/200
# 55/55 - 0s - loss: 0.0065 - 284ms/epoch - 5ms/step
# Epoch 190/200
# 55/55 - 0s - loss: 0.0066 - 280ms/epoch - 5ms/step
# Epoch 191/200
# 55/55 - 0s - loss: 0.0065 - 281ms/epoch - 5ms/step
# Epoch 192/200
# 55/55 - 0s - loss: 0.0064 - 283ms/epoch - 5ms/step
# Epoch 193/200
# 55/55 - 0s - loss: 0.0065 - 279ms/epoch - 5ms/step
# Epoch 194/200
# 55/55 - 0s - loss: 0.0066 - 283ms/epoch - 5ms/step
# Epoch 195/200
# 55/55 - 0s - loss: 0.0065 - 290ms/epoch - 5ms/step
# Epoch 196/200
# 55/55 - 0s - loss: 0.0066 - 276ms/epoch - 5ms/step
# Epoch 197/200
# 55/55 - 0s - loss: 0.0066 - 292ms/epoch - 5ms/step
# Epoch 198/200
# 55/55 - 0s - loss: 0.0065 - 283ms/epoch - 5ms/step
# Epoch 199/200
# 55/55 - 0s - loss: 0.0065 - 282ms/epoch - 5ms/step
# Epoch 200/200
# 55/55 - 0s - loss: 0.0065 - 283ms/epoch - 5ms/step
# 55/55 [==============================] - 2s 2ms/step
# 14/14 [==============================] - 0s 2ms/step
# C:\Users\rutvi\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Mean Squared Error for NOx-H24: 157.2581243831108
# CPU times: total: 1min 14s
# Wall time: 1min 25s
# C:\Users\rutvi\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
